# %%
import requests
import csv
import os
import re
import io
import calendar
from PyPDF2 import PdfReader

# desired location for all data, in this case a new 'data' folder:
DATA_DIR = r"C:\Users\Indel\OneDrive\Documents\Data Science RA\gatewayinitiative-lawrencepd\data"

# regex to match filenames like "01-20-2018.pdf" (case-insensitive).
# remove the .pdf extension before matching, so that part is optional in the regex.
DATE_PATTERN = re.compile(r"^(\d{2})-(\d{2})-(\d{4})$", re.IGNORECASE)

def download_pdfs(
        
    # url format for the PDFs, with a placeholder for the ID
    start_id=2274,
    end_id=49898,
    base_url="https://lawpd.com/DocumentCenter/View/{}",
    failure_csv="failures.csv"
):
    """
    Download PDFs by incrementing through IDs, skipping failures,
    organizing them by date if the filename is in MM-DD-YYYY format,
    or else placing them in a fallback 'no_date' folder with a
    best-effort headline-based filename. Logs errors to a CSV file.
    """

    # ensure the base data directory exists
    os.makedirs(DATA_DIR, exist_ok=True)

    # build a path to the failures.csv in the data directory
    failure_csv_path = os.path.join(DATA_DIR, failure_csv)

    # open CSV file to log failures
    with open(failure_csv_path, mode="w", newline="", encoding="utf-8") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["ID", "Error"])  # header row

        for file_id in range(start_id, end_id + 1):
            url = base_url.format(file_id)

            try:
                response = requests.get(url, timeout=10)  # 10-second timeout
                status_code = response.status_code

                # check HTTP status
                if status_code != 200:
                    writer.writerow([file_id, f"HTTP status {status_code}"])
                    continue

                # check for PDF content
                content_type = response.headers.get("Content-Type", "").lower()
                if "pdf" not in content_type:
                    writer.writerow([file_id, f"Not a PDF (content-type: {content_type})"])
                    continue

                # attempt to get the raw server filename from Content-Disposition
                content_disp = response.headers.get("Content-Disposition", "")
                server_filename = get_filename_from_content_disposition(content_disp)

                # if the server doesn't provide a filename, fallback to ID #, e.g. "2274.pdf"
                if not server_filename:
                    server_filename = f"{file_id}.pdf"

                # ensure .pdf extension
                if not server_filename.lower().endswith(".pdf"):
                    server_filename += ".pdf"

                # try parsing a date from the filename
                year, month, day = parse_date_from_filename(server_filename)

                # if date is parseable, build the nested folder path
                if year is not None:
                    # example: 2018_law_pd_data -> 2018_january
                    year_folder = f"{year}_law_pd_data"
                    month_name = calendar.month_name[month].lower()  # 'january', 'february', etc.
                    month_folder = f"{year}_{month_name}"

                    year_folder_path = os.path.join(DATA_DIR, year_folder)
                    month_folder_path = os.path.join(year_folder_path, month_folder)

                    # create subdirectories
                    os.makedirs(month_folder_path, exist_ok=True)

                    # final path for the PDF
                    file_path = os.path.join(month_folder_path, server_filename)

                else:
                    # if we can't parse a date, try extracting the first page headline
                    pdf_bytes = response.content
                    headline = extract_pdf_headline(pdf_bytes)

                    if headline:
                        safe_headline = sanitize_filename(headline)
                        fallback_name = f"{file_id}_{safe_headline}.pdf"
                    else:
                        fallback_name = f"{file_id}_no_headline.pdf"

                    fallback_folder_path = os.path.join(DATA_DIR, "no_date")
                    os.makedirs(fallback_folder_path, exist_ok=True)

                    file_path = os.path.join(fallback_folder_path, fallback_name)

                # write the PDF content to disk
                with open(file_path, "wb") as out_file:
                    out_file.write(response.content)

            except Exception as e:
                # log any exception (network errors, parse errors, etc.)
                writer.writerow([file_id, str(e)])
                continue


def get_filename_from_content_disposition(content_disp):
    """
    Attempt to parse the filename= value from a Content-Disposition header.
    Returns None if not found.
    Example header: 'attachment; filename="01-20-2018.pdf"'
    """
    if "filename=" in content_disp.lower():
        parts = content_disp.split("filename=")
        if len(parts) > 1:
            # Remove surrounding quotes or semicolons
            filename_part = parts[1].strip().strip('"').strip(';')
            return filename_part
    return None


def parse_date_from_filename(filename):
    """
    Given a filename like '01-20-2018.pdf', parse it as MM-DD-YYYY.
    Returns (year, month, day) if successful, or (None, None, None) if not.
    """
    # strip off '.pdf'
    base_name = os.path.splitext(filename)[0]
    match = DATE_PATTERN.match(base_name)
    if not match:
        return (None, None, None)

    mm = int(match.group(1))
    dd = int(match.group(2))
    yyyy = int(match.group(3))

    # very basic date validity check
    if 1 <= mm <= 12 and 1 <= dd <= 31:
        return (yyyy, mm, dd)
    else:
        return (None, None, None)


def extract_pdf_headline(pdf_bytes):
    """
    Try reading the first page of a PDF to get the first line of text.
    Returns that line (string) or None if it fails or no text is found.
    """
    try:
        pdf_stream = io.BytesIO(pdf_bytes)
        pdf_reader = PdfReader(pdf_stream)
        if len(pdf_reader.pages) > 0:
            first_page = pdf_reader.pages[0]
            text = first_page.extract_text() or ""
            lines = text.splitlines()
            if lines:
                # return the first non-empty line
                return lines[0].strip()
        return None
    except:
        return None


def sanitize_filename(name):
    """
    remove or replace characters that are problematic in filenames,
    returning a safer string. Also truncates to a reasonable length.
    """
    # replace anything not alphanumeric, underscore, or dash with underscore
    safe = re.sub(r"[^a-zA-Z0-9_\-]+", "_", name)
    # limit length (here to 50 chars)
    return safe[:50]

# %%
download_pdfs()
# Out:
# unknown widths :
# [0, IndirectObject(42, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(46, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(50, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(54, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(58, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(62, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(66, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(70, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(74, 0, 1902545055680)]
# unknown widths :
# [0, IndirectObject(54, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(58, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(62, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(66, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(70, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(74, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(78, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(82, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(86, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(90, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(94, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(98, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(102, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(106, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(52, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(56, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(60, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(64, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(68, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(72, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(76, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(80, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(84, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(88, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(92, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(96, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(100, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(52, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(56, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(60, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(64, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(68, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(72, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(76, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(80, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(84, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(88, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(92, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(96, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(100, 0, 1902545054976)]
# unknown widths :
# [0, IndirectObject(333, 0, 1902545049696)]
# unknown widths :
# [0, IndirectObject(328, 0, 1902545049696)]
# unknown widths :
# [0, IndirectObject(323, 0, 1902545049696)]
# unknown widths :
# [0, IndirectObject(318, 0, 1902545049696)]
# unknown widths :
# [0, IndirectObject(313, 0, 1902545049696)]
# unknown widths :
# [0, IndirectObject(308, 0, 1902545049696)]
# unknown widths :
# [0, IndirectObject(43, 0, 1902545046880)]
# unknown widths :
# [0, IndirectObject(38, 0, 1902545046880)]
# unknown widths :
# [0, IndirectObject(33, 0, 1902545046880)]
# unknown widths :
# [0, IndirectObject(28, 0, 1902545046880)]
# unknown widths :
# [0, IndirectObject(23, 0, 1902545046880)]
# unknown widths :
# [0, IndirectObject(61, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(56, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(51, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(46, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(41, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(36, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(31, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(26, 0, 1902545053216)]
# unknown widths :
# [0, IndirectObject(85, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(89, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(93, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(97, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(101, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(105, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(109, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(113, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(117, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(121, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(125, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(129, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(133, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(137, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(141, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(145, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(149, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(153, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(157, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(161, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(165, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(169, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(173, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(177, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(181, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(185, 0, 1902545054800)]
# unknown widths :
# [0, IndirectObject(189, 0, 1902545054800)]
# Multiple definitions in dictionary at byte 0xf9617 for key /PageMode
# unknown widths :
# [0, IndirectObject(49, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(53, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(57, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(61, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(65, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(69, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(73, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(77, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(81, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(59, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(63, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(67, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(71, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(75, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(79, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(83, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(87, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(91, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(95, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(99, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(103, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(107, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(111, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(115, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(119, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(123, 0, 1902545049872)]
# unknown widths :
# [0, IndirectObject(97, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(92, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(87, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(82, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(77, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(72, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(67, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(62, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(57, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(52, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(47, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(42, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(37, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(32, 0, 1902451584608)]
# unknown widths :
# [0, IndirectObject(71, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(66, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(61, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(56, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(51, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(46, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(41, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(36, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(31, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(26, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(59, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(54, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(49, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(44, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(39, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(34, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(29, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(45, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(49, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(53, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(57, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(61, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(65, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(69, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(73, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(77, 0, 1902545053568)]
# unknown widths :
# [0, IndirectObject(43, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(47, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(51, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(55, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(59, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(63, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(67, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(71, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(75, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(79, 0, 1902545056032)]
# unknown widths :
# [0, IndirectObject(40, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(44, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(48, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(52, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(56, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(60, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(64, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(68, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(72, 0, 1902545054448)]
# unknown widths :
# [0, IndirectObject(283, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(278, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(273, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(268, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(263, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(258, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(253, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(248, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(243, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(238, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(233, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(228, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(223, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(218, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(213, 0, 1902545053392)]
# unknown widths :
# [0, IndirectObject(54, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(58, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(62, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(66, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(70, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(74, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(78, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(82, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(86, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(90, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(94, 0, 1902545054272)]
# unknown widths :
# [0, IndirectObject(98, 0, 1902545054272)]

# %% [markdown]
# ## Operation 2023, 2024

# %%
import os
import requests
import re
import calendar
from datetime import datetime

# Base data path using current notebook directory
notebook_dir = os.getcwd()
PDF_DATA_DIR = os.path.join(notebook_dir, '..', 'data', 'pdfs')

# Date format: MM-DD-YYYY
DATE_PATTERN = re.compile(r"^(\d{2})-(\d{2})-(2018|2019|2020|2021|2022)\.pdf$", re.IGNORECASE)

def get_filename_from_content_disposition(header):
    if "filename=" in header.lower():
        return header.split("filename=")[-1].strip('"; ')
    return None

def parse_date_from_filename(filename):
    match = DATE_PATTERN.match(filename)
    if match:
        mm, dd, yyyy = int(match.group(1)), int(match.group(2)), int(match.group(3))
        return yyyy, mm, dd
    return None, None, None

def download_pdfs(start_id=45274, end_id=65274):
    os.makedirs(PDF_DATA_DIR, exist_ok=True)
    total = end_id - start_id + 1

    for count, doc_id in enumerate(range(start_id, end_id + 1), start=1):
        if count % 500 == 0:
            print(f"📦 Progress: {count} / {total} checked")

        url = f"https://lawpd.com/DocumentCenter/View/{doc_id}"
        try:
            res = requests.get(url, timeout=10)
            if res.status_code != 200 or "pdf" not in res.headers.get("Content-Type", "").lower():
                continue

            filename = get_filename_from_content_disposition(res.headers.get("Content-Disposition", ""))
            if not filename or not filename.lower().endswith(".pdf"):
                continue

            year, month, day = parse_date_from_filename(filename)
            if year is None:
                continue

            # Build folder path: .../data/pdfs/2023_january
            month_folder = f"{year}_{calendar.month_name[month].lower()}"
            save_dir = os.path.join(PDF_DATA_DIR, month_folder)
            os.makedirs(save_dir, exist_ok=True)

            save_path = os.path.join(save_dir, filename)
            with open(save_path, "wb") as f:
                f.write(res.content)

            print(f"[{count}/{total}] ✅ Saved: {filename}")

        except Exception:
            continue

# %%
download_pdfs()
# Out:
# [30/20001] ✅ Saved: 05-24-2022.pdf
# [31/20001] ✅ Saved: 05-25-2022.pdf
# [32/20001] ✅ Saved: 05-26-2022.pdf
# [33/20001] ✅ Saved: 05-27-2022.pdf
# [34/20001] ✅ Saved: 05-28-2022.pdf
# [35/20001] ✅ Saved: 05-29-2022.pdf
# [36/20001] ✅ Saved: 05-30-2022.pdf
# [37/20001] ✅ Saved: 05-31-2022.pdf
# [38/20001] ✅ Saved: 05-03-2022.pdf
# [39/20001] ✅ Saved: 05-04-2022.pdf
# [40/20001] ✅ Saved: 05-05-2022.pdf
# [41/20001] ✅ Saved: 05-06-2022.pdf
# [42/20001] ✅ Saved: 05-07-2022.pdf
# [43/20001] ✅ Saved: 05-08-2022.pdf
# [44/20001] ✅ Saved: 05-09-2022.pdf
# [45/20001] ✅ Saved: 05-10-2022.pdf
# [46/20001] ✅ Saved: 05-11-2022.pdf
# [47/20001] ✅ Saved: 05-12-2022.pdf
# [48/20001] ✅ Saved: 05-13-2022.pdf
# [49/20001] ✅ Saved: 05-14-2022.pdf
# [50/20001] ✅ Saved: 05-15-2022.pdf
# [51/20001] ✅ Saved: 05-16-2022.pdf
# [52/20001] ✅ Saved: 05-17-2022.pdf
# [53/20001] ✅ Saved: 05-18-2022.pdf
# [54/20001] ✅ Saved: 05-19-2022.pdf
# [55/20001] ✅ Saved: 05-20-2022.pdf
# [56/20001] ✅ Saved: 05-21-2022.pdf
# [57/20001] ✅ Saved: 05-22-2022.pdf
# [58/20001] ✅ Saved: 05-23-2022.pdf
# [59/20001] ✅ Saved: 06-17-2022.pdf
# [60/20001] ✅ Saved: 06-18-2022.pdf
# [61/20001] ✅ Saved: 06-19-2022.pdf
# [62/20001] ✅ Saved: 06-20-2022.pdf
# [63/20001] ✅ Saved: 06-21-2022.pdf
# [64/20001] ✅ Saved: 06-22-2022.pdf
# [65/20001] ✅ Saved: 06-01-2022.pdf
# [66/20001] ✅ Saved: 06-02-2022.pdf
# [67/20001] ✅ Saved: 06-03-2022.pdf
# [68/20001] ✅ Saved: 06-04-2022.pdf
# [69/20001] ✅ Saved: 06-05-2022.pdf
# [70/20001] ✅ Saved: 06-06-2022.pdf
# [71/20001] ✅ Saved: 06-07-2022.pdf
# [72/20001] ✅ Saved: 06-08-2022.pdf
# [73/20001] ✅ Saved: 06-09-2022.pdf
# [74/20001] ✅ Saved: 06-10-2022.pdf
# [75/20001] ✅ Saved: 06-11-2022.pdf
# [76/20001] ✅ Saved: 06-12-2022.pdf
# [77/20001] ✅ Saved: 06-13-2022.pdf
# [78/20001] ✅ Saved: 06-14-2022.pdf
# [79/20001] ✅ Saved: 06-15-2022.pdf
# [80/20001] ✅ Saved: 06-16-2022.pdf
# [86/20001] ✅ Saved: 06-25-2022.pdf
# [87/20001] ✅ Saved: 06-26-2022.pdf
# [88/20001] ✅ Saved: 06-23-2022.pdf
# [89/20001] ✅ Saved: 06-24-2022.pdf
# [98/20001] ✅ Saved: 06-27-2022.pdf
# [127/20001] ✅ Saved: 06-29-2022.pdf
# [128/20001] ✅ Saved: 06-30-2022.pdf
# [129/20001] ✅ Saved: 06-28-2022.pdf
# [130/20001] ✅ Saved: 07-03-2022.pdf
# [131/20001] ✅ Saved: 07-04-2022.pdf
# [132/20001] ✅ Saved: 07-01-2022.pdf
# [133/20001] ✅ Saved: 07-02-2022.pdf
# [137/20001] ✅ Saved: 07-05-2022.pdf
# [145/20001] ✅ Saved: 07-06-2022.pdf
# [176/20001] ✅ Saved: 07-08-2022.pdf
# [177/20001] ✅ Saved: 07-09-2022.pdf
# [178/20001] ✅ Saved: 07-07-2022.pdf
# [179/20001] ✅ Saved: 07-10-2022.pdf
# [194/20001] ✅ Saved: 07-11-2022.pdf
# [195/20001] ✅ Saved: 07-12-2022.pdf
# [196/20001] ✅ Saved: 07-13-2022.pdf
# [197/20001] ✅ Saved: 07-14-2022.pdf
# [204/20001] ✅ Saved: 07-15-2022.pdf
# [205/20001] ✅ Saved: 07-16-2022.pdf
# [213/20001] ✅ Saved: 07-17-2022.pdf
# [225/20001] ✅ Saved: 07-18-2022.pdf
# [232/20001] ✅ Saved: 07-19-2022.pdf
# [238/20001] ✅ Saved: 07-20-2022.pdf
# [255/20001] ✅ Saved: 07-21-2022.pdf
# [257/20001] ✅ Saved: 07-23-2022.pdf
# [258/20001] ✅ Saved: 07-24-2022.pdf
# [265/20001] ✅ Saved: 07-25-2022.pdf
# [285/20001] ✅ Saved: 07-26-2022.pdf
# [286/20001] ✅ Saved: 07-27-2022.pdf
# [296/20001] ✅ Saved: 07-28-2022.pdf
# [300/20001] ✅ Saved: 07-29-2022.pdf
# [301/20001] ✅ Saved: 07-30-2022.pdf
# [302/20001] ✅ Saved: 07-31-2022.pdf
# [323/20001] ✅ Saved: 08-01-2022.pdf
# [324/20001] ✅ Saved: 08-02-2022.pdf
# [325/20001] ✅ Saved: 08-03-2022.pdf
# [328/20001] ✅ Saved: 08-04-2022.pdf
# [332/20001] ✅ Saved: 08-05-2022.pdf
# [333/20001] ✅ Saved: 08-06-2022.pdf
# [336/20001] ✅ Saved: 08-07-2022.pdf
# [342/20001] ✅ Saved: 08-08-2022.pdf
# [344/20001] ✅ Saved: 08-09-2022.pdf
# [347/20001] ✅ Saved: 08-10-2022.pdf
# [367/20001] ✅ Saved: 08-11-2022.pdf
# [368/20001] ✅ Saved: 08-12-2022.pdf
# [369/20001] ✅ Saved: 08-13-2022.pdf
# [371/20001] ✅ Saved: 08-14-2022.pdf
# [376/20001] ✅ Saved: 08-15-2022.pdf
# [387/20001] ✅ Saved: 08-16-2022.pdf
# [388/20001] ✅ Saved: 08-17-2022.pdf
# [389/20001] ✅ Saved: 08-18-2022.pdf
# [399/20001] ✅ Saved: 08-19-2022.pdf
# [400/20001] ✅ Saved: 08-20-2022.pdf
# [403/20001] ✅ Saved: 08-21-2022.pdf
# [407/20001] ✅ Saved: 08-22-2022.pdf
# [411/20001] ✅ Saved: 08-23-2022.pdf
# [422/20001] ✅ Saved: 08-24-2022.pdf
# [423/20001] ✅ Saved: 08-25-2022.pdf
# [424/20001] ✅ Saved: 08-26-2022.pdf
# [425/20001] ✅ Saved: 08-27-2022.pdf
# [426/20001] ✅ Saved: 08-28-2022.pdf
# [432/20001] ✅ Saved: 08-29-2022.pdf
# [436/20001] ✅ Saved: 08-30-2022.pdf
# [438/20001] ✅ Saved: 08-31-2022.pdf
# [449/20001] ✅ Saved: 09-01-2022.pdf
# [450/20001] ✅ Saved: 09-02-2022.pdf
# [451/20001] ✅ Saved: 09-03-2022.pdf
# [463/20001] ✅ Saved: 09-04-2022.pdf
# [464/20001] ✅ Saved: 09-05-2022.pdf
# [465/20001] ✅ Saved: 09-04-2022.pdf
# [466/20001] ✅ Saved: 09-05-2022.pdf
# [474/20001] ✅ Saved: 09-06-2022.pdf
# [486/20001] ✅ Saved: 09-07-2022.pdf
# [490/20001] ✅ Saved: 09-08-2022.pdf
# [494/20001] ✅ Saved: 09-09-2022.pdf
# [495/20001] ✅ Saved: 09-10-2022.pdf
# 📦 Progress: 500 / 20001 checked
# [500/20001] ✅ Saved: 09-11-2022.pdf
# [503/20001] ✅ Saved: 09-12-2022.pdf
# [514/20001] ✅ Saved: 09-13-2022.pdf
# [531/20001] ✅ Saved: 09-14-2022.pdf
# [536/20001] ✅ Saved: 09-15-2022.pdf
# [539/20001] ✅ Saved: 09-16-2022.pdf
# [540/20001] ✅ Saved: 09-17-2022.pdf
# [541/20001] ✅ Saved: 09-18-2022.pdf
# [549/20001] ✅ Saved: 09-19-2022.pdf
# [552/20001] ✅ Saved: 09-20-2022.pdf
# [557/20001] ✅ Saved: 09-21-2022.pdf
# [568/20001] ✅ Saved: 09-22-2022.pdf
# [572/20001] ✅ Saved: 09-23-2022.pdf
# [573/20001] ✅ Saved: 09-24-2022.pdf
# [574/20001] ✅ Saved: 09-25-2022.pdf
# [579/20001] ✅ Saved: 09-26-2022.pdf
# [584/20001] ✅ Saved: 09-27-2022.pdf
# [585/20001] ✅ Saved: 09-28-2022.pdf
# [599/20001] ✅ Saved: 09-29-2022.pdf
# [604/20001] ✅ Saved: 09-30-2022.pdf
# [615/20001] ✅ Saved: 10-01-2022.pdf
# [616/20001] ✅ Saved: 10-02-2022.pdf
# [622/20001] ✅ Saved: 10-03-2022.pdf
# [624/20001] ✅ Saved: 10-04-2022.pdf
# [629/20001] ✅ Saved: 10-05-2022.pdf
# [637/20001] ✅ Saved: 10-06-2022.pdf
# [638/20001] ✅ Saved: 10-07-2022.pdf
# [640/20001] ✅ Saved: 10-08-2022.pdf
# [641/20001] ✅ Saved: 10-09-2022.pdf
# [642/20001] ✅ Saved: 10-10-2022.pdf
# [644/20001] ✅ Saved: 10-11-2022.pdf
# [645/20001] ✅ Saved: 10-12-2022.pdf
# [654/20001] ✅ Saved: 10-14-2022.pdf
# [655/20001] ✅ Saved: 10-15-2022.pdf
# [659/20001] ✅ Saved: 10-16-2022.pdf
# [662/20001] ✅ Saved: 10-17-2022.pdf
# [672/20001] ✅ Saved: 10-18-2022.pdf
# [675/20001] ✅ Saved: 10-19-2022.pdf
# [677/20001] ✅ Saved: 10-22-2022.pdf
# [693/20001] ✅ Saved: 10-25-2022.pdf
# [696/20001] ✅ Saved: 10-26-2022.pdf
# [698/20001] ✅ Saved: 10-27-2022.pdf
# [728/20001] ✅ Saved: 10-28-2022.pdf
# [729/20001] ✅ Saved: 10-29-2022.pdf
# [730/20001] ✅ Saved: 10-30-2022.pdf
# [731/20001] ✅ Saved: 10-31-2022.pdf
# [732/20001] ✅ Saved: 11-01-2022.pdf
# [733/20001] ✅ Saved: 11-02-2022.pdf
# [739/20001] ✅ Saved: 11-03-2022.pdf
# [752/20001] ✅ Saved: 11-04-2022.pdf
# [753/20001] ✅ Saved: 11-05-2022.pdf
# [754/20001] ✅ Saved: 11-06-2022.pdf
# [755/20001] ✅ Saved: 11-07-2022.pdf
# [771/20001] ✅ Saved: 11-08-2022.pdf
# [772/20001] ✅ Saved: 11-09-2022.pdf
# [776/20001] ✅ Saved: 11-10-2022.pdf
# [777/20001] ✅ Saved: 11-11-2022.pdf
# [783/20001] ✅ Saved: 11-12-2022.pdf
# [784/20001] ✅ Saved: 11-13-2022.pdf
# [788/20001] ✅ Saved: 11-14-2022.pdf
# [794/20001] ✅ Saved: 11-15-2022.pdf
# [802/20001] ✅ Saved: 11-16-2022.pdf
# [803/20001] ✅ Saved: 11-17-2022.pdf
# [807/20001] ✅ Saved: 11-18-2022.pdf
# [808/20001] ✅ Saved: 11-19-2022.pdf
# [810/20001] ✅ Saved: 11-20-2022.pdf
# [817/20001] ✅ Saved: 11-21-2022.pdf
# [821/20001] ✅ Saved: 11-22-2022.pdf
# [822/20001] ✅ Saved: 11-23-2022.pdf
# [823/20001] ✅ Saved: 11-24-2022.pdf
# [825/20001] ✅ Saved: 11-25-2022.pdf
# [826/20001] ✅ Saved: 11-26-2022.pdf
# [827/20001] ✅ Saved: 11-27-2022.pdf
# [852/20001] ✅ Saved: 11-28-2022.pdf
# [853/20001] ✅ Saved: 11-29-2022.pdf
# [854/20001] ✅ Saved: 11-30-2022.pdf
# [867/20001] ✅ Saved: 12-01-2022.pdf
# [868/20001] ✅ Saved: 12-02-2022.pdf
# [869/20001] ✅ Saved: 12-03-2022.pdf
# [871/20001] ✅ Saved: 12-04-2022.pdf
# [872/20001] ✅ Saved: 12-05-2022.pdf
# [880/20001] ✅ Saved: 12-06-2022.pdf
# [885/20001] ✅ Saved: 12-07-2022.pdf
# [890/20001] ✅ Saved: 12-08-2022.pdf
# [897/20001] ✅ Saved: 12-09-2022.pdf
# [898/20001] ✅ Saved: 12-10-2022.pdf
# [902/20001] ✅ Saved: 12-11-2022.pdf
# [906/20001] ✅ Saved: 12-12-2022.pdf
# [912/20001] ✅ Saved: 12-13-2022.pdf
# [918/20001] ✅ Saved: 12-14-2022.pdf
# [927/20001] ✅ Saved: 12-16-2022.pdf
# [929/20001] ✅ Saved: 12-17-2022.pdf
# [932/20001] ✅ Saved: 12-18-2022.pdf
# [933/20001] ✅ Saved: 12-19-2022.pdf
# [937/20001] ✅ Saved: 12-20-2022.pdf
# [938/20001] ✅ Saved: 12-21-2022.pdf
# [943/20001] ✅ Saved: 12-22-2022.pdf
# [945/20001] ✅ Saved: 12-24-2022.pdf
# [946/20001] ✅ Saved: 12-25-2022.pdf
# [947/20001] ✅ Saved: 12-26-2022.pdf
# [951/20001] ✅ Saved: 12-27-2022.pdf
# [952/20001] ✅ Saved: 12-28-2022.pdf
# [962/20001] ✅ Saved: 12-29-2022.pdf
# [963/20001] ✅ Saved: 12-30-2022.pdf
# [965/20001] ✅ Saved: 12-31-2022.pdf
# 📦 Progress: 1000 / 20001 checked
# 📦 Progress: 1500 / 20001 checked
# 📦 Progress: 2000 / 20001 checked
# 📦 Progress: 2500 / 20001 checked
# 📦 Progress: 3000 / 20001 checked
# 📦 Progress: 3500 / 20001 checked
# 📦 Progress: 4000 / 20001 checked
# 📦 Progress: 4500 / 20001 checked
# 📦 Progress: 5000 / 20001 checked
# 📦 Progress: 5500 / 20001 checked
# 📦 Progress: 6000 / 20001 checked
# 📦 Progress: 6500 / 20001 checked
# 📦 Progress: 7000 / 20001 checked
# 📦 Progress: 7500 / 20001 checked
# 📦 Progress: 8000 / 20001 checked
# 📦 Progress: 8500 / 20001 checked
# 📦 Progress: 9000 / 20001 checked
# 📦 Progress: 9500 / 20001 checked
# 📦 Progress: 10000 / 20001 checked
# 📦 Progress: 10500 / 20001 checked
# 📦 Progress: 11000 / 20001 checked
# 📦 Progress: 11500 / 20001 checked
# 📦 Progress: 12000 / 20001 checked
# 📦 Progress: 12500 / 20001 checked
# 📦 Progress: 13000 / 20001 checked
# 📦 Progress: 13500 / 20001 checked
# 📦 Progress: 14000 / 20001 checked
# 📦 Progress: 14500 / 20001 checked
# 📦 Progress: 15000 / 20001 checked
# 📦 Progress: 15500 / 20001 checked
# 📦 Progress: 16000 / 20001 checked
# 📦 Progress: 16500 / 20001 checked
# 📦 Progress: 17000 / 20001 checked
# 📦 Progress: 17500 / 20001 checked
# 📦 Progress: 18000 / 20001 checked
# 📦 Progress: 18500 / 20001 checked
# 📦 Progress: 19000 / 20001 checked
# 📦 Progress: 19500 / 20001 checked
# 📦 Progress: 20000 / 20001 checked
